# %% [markdown]
# ## Exercício para os três tipos básicos de gráficos
#
# Você recebeu, na forma de listas, os dados de receita anual de uma empresa de tecnologia, em bilhões de dólares, nos últimos anos. Com esses dados, você deve criar três gráficos, um de cada tipo abaixo listado, para visualizar esses dados. Os gráficos devem conter título e rótulos dos eixos. O nome da empresa é "Apple Inc.".
#
# Tipos de gráficos:
#
# - Gráfico de linhas
#   - além da linha, mostre os pontos de cada valor
# - Gráfico de barras
#   - adicione o valor de cada barra no gráfico
# - Gráfico de dispersão
#   - ligue a grade do gráfico
#
# Cada gráfico deve usar uma paleta de cores diferente.
#
# Os dados são:
#
# Ano | Receita (em bilhões de dólares)
# --- | ---
# | 2009 | 42,9
# | 2010 | 65,2
# | 2011 | 108,2
# | 2012 | 156,5
# | 2013 | 170,9
# | 2014 | 182,8
# | 2015 | 233,7
# | 2016 | 215,6
# | 2017 | 229,2
# | 2018 | 265,6
# | 2019 | 260,2
# | 2020 | 274,5
# | 2021 | 365,8
# | 2022 | 394,3
#
# Qual o tipo de gráfico mais adequado para visualizar esses dados?

# %%
# convertendo os dados para listas
ano = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
receita = [42.9, 65.2, 108.2, 156.5, 170.9, 182.8, 233.7, 215.6, 229.2, 265.6, 260.2, 274.5, 365.8, 394.3]

# %%
import matplotlib.pyplot as plt
from cycler import cycler
# gráfico de linhas


cores_cycler = cycler('color', plt.get_cmap('Pastel2').colors)
plt.rc('axes', prop_cycle=cores_cycler)

plt.plot(ano, receita, marker='o')
plt.plot(ano, [30.5, 15.2, 20.2, 156.5, 20.9, 240.8, 233.7, 150.6, 229.2, 250.6, 150.2, 250.5, 320.8, 350.3], marker='x')

plt.xlabel('Ano')
plt.ylabel('receita anual (em bilhões de reais')
plt.title('Evolução')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
# gráfico de linhas

plt.figure(figsize=(10, 4))
barras = plt.bar(ano, receita)
#colocar numero em cima da barra.
plt.bar_label(barras)

#ou cores = plt.get_cmap('Set3').colors e setar no barras = plt.bar(ano, receita, color=cores[0)
cores_cycler = cycler('color', plt.get_cmap('Set3').colors)
plt.rc('axes', prop_cycle=cores_cycler)

#ticks -> x = eixo e ticks para deixar paralelo os anos. rotation para rotacionar  
plt.xticks(ano, rotation=40)

plt.xlabel('Ano')
plt.ylabel('receita anual (em bilhões de reais')
plt.title('Evolução')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
# gráfico de linhas



cores_cycler = cycler('color', plt.get_cmap('Accent').colors)
plt.rc('axes', prop_cycle=cores_cycler)

plt.bar(ano, receita)

plt.xlabel('Ano')
plt.ylabel('receita anual (em bilhões de reais')
plt.title('Evolução')

plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler
# gráfico de linhas



cores_cycler = cycler('color', plt.get_cmap('Accent').colors)
plt.rc('axes', prop_cycle=cores_cycler)


plt.scatter(ano, receita, s=receita, c=receita, cmap='Reds') #c=receita(atrelado a receita a cor), cmap = sequencia cor. obs: Reds_r (reverse)
plt.xticks(ano, rotation=40)

plt.grid(True, linestyle='dashdot') #dolid, dotted, --, - , : , dashdot, long dash with offset

plt.xlabel('Ano')
plt.ylabel('receita anual (em bilhões de reais')
plt.title('Evolução')

plt.colorbar(orientation='')

plt.show()
